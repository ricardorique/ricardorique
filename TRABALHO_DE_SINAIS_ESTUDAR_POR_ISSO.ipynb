# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardorique/ricardorique/blob/main/TRABALHO_DE_SINAIS_ESTUDAR_POR_ISSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TRABALHO DE SINAIS PARA PODER COMER COXINHA NO INTERVALO

# %%
#atividade
#CRIAR UM SINAL ARTIFICIAL
# PLOTAR O SINAL
#CALCULAR O FFT DO SINAL
#PLOTAR O FFT DO SINAL CORRETAMENTE
# selecionar celula sempre quando importar algo
import numpy as np #biblioteca que usei para criar o sinal artificial
import matplotlib.pyplot as plt #biblioteca que usei para plotar (criar o grafico)
import scipy# biblioteca que utilizei para colocar a transformada de fourier

# %% [markdown]
# Criando o Sinal Artificial

# %%
freq = 10
tempo = np.linspace (0,1,1000)#a linha do tempo, o 0 é o inicio o 1 é o fim e o 1000 é a quantidade do t
fase = 20
amp = 25

# %%
sinal = amp*np.sin(2*np.pi*freq*tempo + fase) + 5 * np.sin(2 * np.pi * 200 * tempo + 25)#função seno amplitude x seno(2pi x frequencia x tempo +fase), com o 5(2*pi*200 de frequencia, * o tempo * 25 de fase) deixa o sinal mais complexo pq tem dois senos somados.

# %%
sinal #printa os pontos do gráfico da função seno.
# Out:
# array([ 2.21618725e+01,  2.79314057e+01,  2.73625561e+01,  2.19378400e+01,
#         1.97314464e+01,  2.42294275e+01,  2.95020435e+01,  2.84114776e+01,
#         2.24924998e+01,  1.98276950e+01,  2.38587031e+01,  2.86227318e+01,
#         2.70087147e+01,  2.06036218e+01,  1.74980829e+01,  2.10891203e+01,
#         2.53810172e+01,  2.32895944e+01,  1.64537771e+01,  1.29717020e+01,
#         1.61953858e+01,  2.00961369e+01,  1.76166224e+01,  1.04473052e+01,
#         6.69312509e+00,  9.66054817e+00,  1.32877067e+01,  1.05439279e+01,
#         3.17065595e+00, -7.21197947e-01,  2.12862000e+00,  5.62475693e+00,
#         2.76291371e+00, -4.66513050e+00, -8.54340279e+00, -5.65858825e+00,
#        -2.13988762e+00, -4.96555713e+00, -1.22941631e+01, -1.60056005e+01,
#        -1.29342260e+01, -9.24344544e+00, -1.18857879e+01, -1.89708195e+01,
#        -2.23751934e+01, -1.89816165e+01, -1.49879932e+01, -1.73213680e+01,
# ...

# %% [markdown]
# PLOTAR O GRAFICO

# %%
plt.plot(sinal) #comando para criar o gráfico

# %% [markdown]
# CALCULO DE FFT (FOURIER) NO SINAL

# %%
scipy.fft.fft(sinal)#coloca a transformada de fourier na função seno
# Out:
# array([ 2.28236313e+01-0.00000000e+00j,  2.30567889e+01-9.56691076e-01j,
#         2.37853458e+01-1.97303138e+00j,  2.51061212e+01-3.12175106e+00j,
#         2.72187334e+01-4.50826704e+00j,  3.05128651e+01-6.30958584e+00j,
#         3.57932759e+01-8.86847404e+00j,  4.49589720e+01-1.29730373e+01j,
#         6.37148866e+01-2.09687487e+01j,  1.20398875e+02-4.44738672e+01j,
#         1.15701339e+04-4.73654251e+03j, -1.11728620e+02+5.01705504e+01j,
#        -5.32184556e+01+2.59890546e+01j, -3.39913459e+01+1.79226177e+01j,
#        -2.44974441e+01+1.38602134e+01j, -1.88759475e+01+1.13983577e+01j,
#        -1.51809584e+01+9.73808579e+00j, -1.25809328e+01+8.53730216e+00j,
#        -1.06612088e+01+7.62493189e+00j, -9.19205705e+00+6.90584043e+00j,
#        -8.03605718e+00+6.32285203e+00j, -7.10605311e+00+5.83949950e+00j,
#        -6.34415670e+00+5.43140301e+00j, -5.71045536e+00+5.08162847e+00j,
#        -5.17656716e+00+4.77803486e+00j, -4.72177883e+00+4.51168195e+00j,
# ...

# %%
sinal_fft = scipy.fft.fft(sinal)# cria a variavel do sinal com fourier

# %% [markdown]
# PLOTAR SINAL COM FFT

# %%
plt.plot(sinal_fft)#mostrar o desenho do gráfico
plt.show()#frescura pra deixar bonitinho.
